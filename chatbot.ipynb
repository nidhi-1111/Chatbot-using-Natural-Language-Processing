# %%
import random
nltk.download('punkt')
nltk.download('wordnet')
import numpy as np
import pandas as pd
import nltk
import string
import random
import nltk
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
f = open('DS.txt', 'r', errors = 'ignore')
preprocessed_text = f.read()
preprocessed_text = preprocessed_text.lower()
sent_tokens = nltk.sent_tokenize(preprocessed_text)
word_tokens = nltk.word_tokenize(preprocessed_text)
# Out:
# ['1.', 'what', 'are', 'the', 'differences', 'between', 'supervised', 'and', 'unsupervised', 'learning', '?', 'supervised', 'learning', 'unsupervised', 'learning', 'uses', 'known', 'and', 'labeled', 'data', 'as', 'input', 'supervised', 'learning', 'has', 'a', 'feedback', 'mechanism', 'the', 'most', 'commonly', 'used', 'supervised', 'learning', 'algorithms', 'are', 'decision', 'trees', ',', 'logistic', 'regression', ',', 'and', 'support', 'vector', 'machine', 'uses', 'unlabeled', 'data', 'as', 'input', 'unsupervised', 'learning', 'has', 'no', 'feedback', 'mechanism', 'the', 'most', 'commonly', 'used', 'unsupervised', 'learning', 'algorithms', 'are', 'k-means', 'clustering', ',', 'hierarchical', 'clustering', ',', 'and', 'apriori', 'algorithm', 'data', 'scientist', 'master', "'s", 'program', 'in', 'collaboration', 'with', 'ibmexplore', 'coursedata', 'scientist', 'master', "'s", 'program', 'logistic', 'regression', 'measures', 'the', 'relationship', 'between', 'the', 'dependent', 'variable', '(', 'our', 'label', 'of', 'what', 'we', 'want', 'to', 'predict', ')', 'and', 'one', 'or', 'more', 'independent', 'variables', '(', 'our', 'features', ')', 'by', 'estimating', 'probability', 'using', 'its', 'underlying', 'logistic', 'function', '(', 'sigmoid', ')', '.', 'the', 'image', 'shown', 'below', 'depicts', 'how', 'logistic', 'regression', 'works', ':', 'logistic-regression', 'the', 'formula', 'and', 'graph', 'for', 'the', 'sigmoid', 'function', 'are', 'as', 'shown', ':', 'sigmoid-function', 'take', 'the', 'entire', 'data', 'set', 'as', 'input', 'calculate', 'entropy', 'of', 'the', 'target', 'variable', ',', 'as', 'well', 'as', 'the', 'predictor', 'attributes', 'calculate', 'your', 'information', 'gain', 'of', 'all', 'attributes', '(', 'we', 'gain', 'information', 'on', 'sorting', 'different', 'objects', 'from', 'each', 'other', ')', 'choose', 'the', 'attribute', 'with', 'the', 'highest', 'information', 'gain', 'as', 'the', 'root', 'node', 'repeat', 'the', 'same', 'procedure', 'on', 'every', 'branch', 'until', 'the', 'decision', 'node', 'of', 'each', 'branch', 'is', 'finalized', 'for', 'example', ',', 'let', "'s", 'say', 'you', 'want', 'to', 'build', 'a', 'decision', 'tree', 'to', 'decide', 'whether', 'you', 'should', 'accept', 'or', 'decline', 'a', 'job', 'offer', '.', 'the', 'decision', 'tree', 'for', 'this', 'case', 'is', 'as', 'shown', ':', 'build', 'a', 'decision', 'tree', 'it', 'is', 'clear', 'from', 'the', 'decision', 'tree', 'that', 'an', 'offer', 'is', 'accepted', 'if', ':', 'salary', 'is', 'greater', 'than', '$', '50,000', 'the', 'commute', 'is', 'less', 'than', 'an', 'hour', 'incentives', 'are', 'offered', 'free', 'course', ':', 'python', 'for', 'beginners', 'master', 'the', 'fundamentals', 'of', 'pythonenroll', 'nowfree', 'course', ':', 'python', 'for', 'beginners', '4.', 'how', 'do', 'you', 'build', 'a', 'random', 'forest', 'model', '?', 'a', 'random', 'forest', 'is', 'built', 'up', 'of', 'a', 'number', 'of', 'decision', 'trees', '.', 'if', 'you', 'split', 'the', 'data', 'into', 'different', 'packages', 'and', 'make', 'a', 'decision', 'tree', 'in', 'each', 'of', 'the', 'different', 'groups', 'of', 'data', ',', 'the', 'random', 'forest', 'brings', 'all', 'those', 'trees', 'together', '.', 'steps', 'to', 'build', 'a', 'random', 'forest', 'model', ':', 'randomly', 'select', "'", 'k', "'", 'features', 'from', 'a', 'total', 'of', "'m", "'", 'features', 'where', 'k', '<', '<', 'm', 'among', 'the', "'", 'k', "'", 'features', ',', 'calculate', 'the', 'node', 'd', 'using', 'the', 'best', 'split', 'point', 'split', 'the', 'node', 'into', 'daughter', 'nodes', 'using', 'the', 'best', 'split', 'repeat', 'steps', 'two', 'and', 'three', 'until', 'leaf', 'nodes', 'are', 'finalized', 'build', 'forest', 'by', 'repeating', 'steps', 'one', 'to', 'four', 'for', "'n", "'", 'times', 'to', 'create', "'n", "'", 'number', 'of', 'trees', '5.', 'how', 'can', 'you', 'avoid', 'overfitting', 'your', 'model', '?', 'overfitting', 'refers', 'to', 'a', 'mode ...

# %%
punctuations = dict((ord(punct), punct) for punct in string.punctuation)

# %%
#preprocessing the text
lem = nltk.stem.WordNetLemmatizer()
def Ltokens(tokens):
  return [lem.lemmatize(token) for token in tokens]
punctuations = dict((ord(punct), None) for punct in string.punctuation)

def Lnorm(text):
  return Ltokens(nltk.word_tokenize(text.lower().translate(punctuations)))

# %%
convo_starter = ('hello', 'hi', 'good morning', 'good afternoon', 'hey', 'ssup', "what's up", 'okay', 'got it', 'understood', 'understand')
convo_res = ['yes', 'tell me', 'good', 'how can i help you?', 'ask me anything about data science']
go_ahead = ['okay', 'got it', 'understood', 'understand']
def start(sentence):
  for word in sentence.split():
    if word.lower() in convo_starter:
      if word in go_ahead:
        return 'Glad that I was able to, ask me next one!'
      else:
        return random.choice(convo_res)

# %%
 from sklearn.feature_extraction.text import TfidfVectorizer
 from sklearn.metrics.pairwise import cosine_similarity

# %%
def reply(user_reply):
  bot_reply = ''
  tfIdfVectorizer=TfidfVectorizer(tokenizer = Lnorm, stop_words = 'english')
  model = tfIdfVectorizer.fit_transform(sent_tokens)
  #df = pd.DataFrame(model[0].T.todense(), index = tfIdfVectorizer.get_feature_names_out(), columns=["TF-IDF"])
  #df = df.sort_values('TF-IDF', ascending=False)
  val = cosine_similarity(model[-1], model)
  idx = val.argsort()[0][-2]
  flat = val.flatten()
  flat.sort()
  req_tfidf = flat[-2]
  if(req_tfidf == 0):
    bot_reply = bot_reply + "I am sorry! I don't understand you, can you please try again"
    return bot_reply
  else:
    bot_reply = bot_reply + sent_tokens[idx]
    return bot_reply

# %%
flag = True
print("Bot: My name is Sara, I'm here to help you with your data science queries. Shoot me your questions ;)")
while(flag==True):
  user_reply = input()
  user_reply = user_reply.lower()
  if(user_reply != 'bye'):
    if(user_reply == 'thanks' or user_reply == 'thank you'):
      flag = False
      print("Nidhi: You're welcome anytime")
    else:
      if(start(user_reply)!= None):
        print("Nidhi:" + start(user_reply))
      else:
        sent_tokens.append(user_reply)
        word_tokens = word_tokens + nltk.word_tokenize(user_reply)
        final_words = list(set(word_tokens))
        print("Nidhi: ", end = "")
        print(reply(user_reply))
        sent_tokens.remove(user_reply)
  else:
    flag = False
    print("Nidhi: Bye, it was nice talking to you!")
# Out:
# Bot: My name is Sara, I'm here to help you with your data science queries. Shoot me your questions ;)
# okay
# Nidhi:Glad that I was able to, ask me next one!
# understand
# Nidhi:Glad that I was able to, ask me next one!
# bye
# Nidhi: Bye, it was nice talking to you!
